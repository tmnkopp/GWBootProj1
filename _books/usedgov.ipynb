# %%
import pandas as pd
import numpy as np 
import re
import requests
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
url = 'https://api.ed.gov/data/mbk-highschool-dropout?api_key=XkJUo7Vd2J9gpPhgA0A1GuUl27ycCdba5y1gkx5s'
print(url)
#response = requests.get(url)
df = pd.read_csv('data/naep12-reading-2016.csv')
df["Score"].dropna(inplace=True) 
scores = set(df["Score"]) 
df
# Out:
# https://api.ed.gov/data/mbk-highschool-dropout?api_key=XkJUo7Vd2J9gpPhgA0A1GuUl27ycCdba5y1gkx5s
#                                       Characteristic     Sex  \
# 0                                              Total     NaN
# 1                                              Total     NaN
# 2                                              Total     NaN
# 3                                              Total     NaN
# 4                                              Total     NaN
# ..                                               ...     ...
# 331  Total - Female, Two or more races, non-Hispanic  Female
# 332  Total - Female, Two or more races, non-Hispanic  Female
# 333  Total - Female, Two or more races, non-Hispanic  Female
# 334  Total - Female, Two or more races, non-Hispanic  Female
# 335  Total - Female, Two or more races, non-Hispanic  Female
#
#                       Race/ethnicity  Year  Score  Standard Error  \
# 0                                NaN  2002  285.0             0.7
# ...
