# %%
import pandas as pd
import numpy as np 
import re  
import json
import seaborn as sns
import matplotlib.pyplot as plt 
import calendar
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df_usvideos = pd.read_csv('data/youtube/USvideos.csv')
json_cats = pd.read_json('data/youtube/US_category_id.json')
df_cats = pd.json_normalize(json_cats['items'])

# %%
#df_cats.info() 
#df_usvideos.info()

# %%
df_cats=df_cats.iloc[:,2:]
#df_usvideos['trending_date'] = df_usvideos['trending_date'].apply(lambda x: re.sub('\.','-',x))
df_cats['id']=df_cats['id'].astype(int) 
cols=["views likes dislikes comment_count".split()]
for col in cols:
    df_usvideos[col]=df_usvideos[col].astype(int)

# %%
df = pd.merge(df_usvideos
              , df_cats
              , left_on=['category_id']
              , right_on=['id']
              , suffixes=['','┌∩┐(◣_◢)┌∩┐']
             )
df.drop(
    [c for c in df.columns if '┌∩┐(◣_◢)┌∩┐' in c]
    , axis=1
    , inplace=True
    )
df_youtube=df

# %%
df_youtube=df[['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
       'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
       'thumbnail_link', 'comments_disabled', 'ratings_disabled',
       'video_error_or_removed', 'description', 'id', 'snippet.channelId',
       'snippet.title']]

# %%
df=df_youtube 
dict_day_name=dict(enumerate(calendar.day_name))  
df['publish_time'] = pd.to_datetime(df['publish_time'])
df['trending_date'] = pd.to_datetime(df['trending_date'],format="%y.%d.%m")
df["Trending_Year"]=df["trending_date"].apply(lambda t:t.year)
df["Trending_Month"]=df["trending_date"].apply(lambda t:t.month)
df["Trending_Day"]=df["trending_date"].apply(lambda t:t.day) 
df["Trending_Day_of_Week"]=df["trending_date"].apply(lambda t:t.dayofweek) 
df["Trending_DOW"]=df["Trending_Day_of_Week"].map(dict_day_name)
df["publish_Year"]=df["publish_time"].apply(lambda t:t.year)
df["publish_Month"]=df["publish_time"].apply(lambda t:t.month)
df["publish_Day"]=df["publish_time"].apply(lambda t:t.day)
df["publish_Day_of_Week"]=df["publish_time"].apply(lambda t:t.dayofweek)
df["publish_DOW"]=df["publish_Day_of_Week"].map(dict_day_name)
df["Publish_Hour"]=df["publish_time"].apply(lambda t:t.hour)  
df["title"]=df["title"].apply(lambda t: ''.join([c for c in t if (c.isalpha()) or (c.isspace())]))
df[2000:len(df):4000]
# Out:
#           video_id trending_date  \
# 2000   hlb3gGNBHFE    2018-03-19
# 6000   ONI_06wGbsQ    2018-01-13
# 10000  dY2jpeasD4w    2018-04-14
# 14000  TU-Z4uPnFeg    2017-12-28
# 18000  BFqNP8VqoPs    2018-03-07
# 22000  LTNOYZ44ywM    2017-12-23
# 26000  tsM6kq-7nmw    2018-06-08
# 30000  2aQykuIaJVI    2018-04-02
# 34000  -kETYvHON_I    2018-01-25
# 38000  8vCn190ti9U    2018-04-15
#
#                                                    title  \
# 2000       THE DIFFERENCE BETWEEN AUSTRALIA  NEW ZEALAND
# 6000                               THINGS THAT ARE LOWER
# 10000  Adam Ruins Everything  The True Origins of Tul...
# 14000             The Funeral  Cyanide  Happiness Shorts
# 18000  Inside a Chinese D Printing Factory  in Shenzh...
# 22000  Amtrak Train Derails Near Olympia Washington  ...
# 26000  Does LeBron need a th title to pass Jordan as ...
# 30000  LinManuel Miranda  Ben Platt Found Tonight Off...
# 34000        Why Dying is Illegal in Longyearbyen Norway
# 38000     DIY Japanese Foil Ball CHALLENGE  Man Vs Balls
#
#                       channel_title  category_id              publish_time  \
# 2000                     How to DAD           22 2018-03-05 01:15:47+00:00
# 6000                      Amber Liu           24 2018-01-12 03:15:43+00:00
# 10000                         truTV           24 2018-04-12 15:00:09+00:00
# 14000          ExplosmEntertainment           23 2017-12-21 06:00:00+00:00
# 18000                 Strange Parts           28 2018-02-28 14:22:40+00:00
# 22000                          CNBC           25 2017-12-18 17:40:48+00:00
# 26000  Skip and Shannon: UNDISPUTED           17 2018-05-30 17:01:39+00:00
# 30000              Atlantic Records           10 2018-03-19 13:00:46+00:00
# 34000           Half as Interesting           27 2018-01-18 15:30:00+00:00
# 38000                  ThreadBanger           26 2018-04-08 00:55:43+00:00
#
#                                                     tags    views   likes  \
# 2000   australia|"ozzy"|"kiwi"|"new zealand"|"bathurs...   643097   23778
# 6000   fx|"amber"|"amber liu"|"kpop"|"luna"|"lower"|"...   109642   21080
# 10000  “truTv|"Shows”"|"”truTV"|"New"|"Series”"|"epis...   337788    6006
# 14000  shorts|"c&hshorts"|"c&h shorts"|"c and h short...  1446140   64501
# 18000  3d printing|"sla 3d printer"|"sla 3d printing"...   274108   12613
# 22000  CNBC|"Mad Money"|"Squawk Box"|"Power Lunch"|"O...   143064     427
# 26000  fox|"fox sports"|"fs1"|"fox sports 1"|"undispu...   727615    6108
# 30000  music|"official"|"music video"|"dear evan hans...  3566092  181493
# 34000  half|"as"|"interesting"|"longyearbyen"|"norway...   597049   18464
# 38000  DIY|"threadbanger"|"Corinne Leigh"|"Rob Czar"|...  1772108   67674
#
#        dislikes  ...  Trending_Month Trending_Day  Trending_Day_of_Week  \
# 2000        447  ...               3           19                     0
# 6000         25  ...               1           13                     5
# 10000       265  ...               4           14                     5
# 14000      2171  ...              12           28                     3
# 18000       168  ...               3            7                     2
# 22000       199  ...              12           23                     5
# 26000      1880  ...               6            8                     4
# 30000      3107  ...               4            2                     0
# 34000      1054  ...               1           25                     3
# 38000      5720  ...               4           15                     6
#
#        Trending_DOW  publish_Year publish_Month  publish_Day  \
# 2000         Monday          2018             3            5
# 6000       Saturday          2018             1           12
# 10000      Saturday          2018             4           12
# 14000      Thursday          2017            12           21
# 18000     Wednesday          2018             2           28
# 22000      Saturday          2017            12           18
# 26000        Friday          2018             5           30
# 30000        Monday          2018             3           19
# 34000      Thursday          2018             1           18
# 38000        Sunday          2018             4            8
#
#       publish_Day_of_Week publish_DOW  Publish_Hour
# 2000                    0      Monday             1
# 6000                    4      Friday             3
# 10000                   3    Thursday            15
# 14000                   3    Thursday             6
# 18000                   2   Wednesday            14
# 22000                   0      Monday            17
# 26000                   2   Wednesday            17
# 30000                   0      Monday            13
# 34000                   3    Thursday            15
# 38000                   6      Sunday             0
#
# [10 rows x 30 columns]

# %%
df=df_youtube
df=df.groupby('video_id', as_index=False).count().sort_values(by='views', ascending=False)  
vids = df[0:100]['video_id']  
df=df_youtube
df=df[df['video_id']==vids.iloc[12]] 
df
# Out:
#           video_id trending_date  \
# 20988  6S9c5nnDd_s    2018-05-16
# 21000  6S9c5nnDd_s    2018-05-17
# 21013  6S9c5nnDd_s    2018-05-18
# 21026  6S9c5nnDd_s    2018-05-19
# 21038  6S9c5nnDd_s    2018-05-20
# 21051  6S9c5nnDd_s    2018-05-21
# 21063  6S9c5nnDd_s    2018-05-22
# 21073  6S9c5nnDd_s    2018-05-23
# 21084  6S9c5nnDd_s    2018-05-24
# 21094  6S9c5nnDd_s    2018-05-25
# 21104  6S9c5nnDd_s    2018-05-26
# 21116  6S9c5nnDd_s    2018-05-27
# 21129  6S9c5nnDd_s    2018-05-28
# 21142  6S9c5nnDd_s    2018-05-29
# 21155  6S9c5nnDd_s    2018-05-30
# 21168  6S9c5nnDd_s    2018-05-31
# 21181  6S9c5nnDd_s    2018-06-01
# 21193  6S9c5nnDd_s    2018-06-02
# 21205  6S9c5nnDd_s    2018-06-03
# 21218  6S9c5nnDd_s    2018-06-04
# 21233  6S9c5nnDd_s    2018-06-05
# 21248  6S9c5nnDd_s    2018-06-06
# 21263  6S9c5nnDd_s    2018-06-07
# 21280  6S9c5nnDd_s    2018-06-08
# 21296  6S9c5nnDd_s    2018-06-09
# 21313  6S9c5nnDd_s    2018-06-10
# 21329  6S9c5nnDd_s    2018-06-11
# 21346  6S9c5nnDd_s    2018-06-12
#
#                                                    title     channel_title  \
# 20988  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21000  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21013  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21026  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21038  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21051  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21063  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21073  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21084  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21094  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21104  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21116  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21129  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21142  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21155  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21168  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21181  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21193  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21205  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21218  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21233  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21248  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21263  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21280  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21296  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21313  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21329  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
# 21346  Bohemian Rhapsody  Teaser Trailer HD  th Centu...  20th Century Fox
#
#        category_id              publish_time  \
# 20988            1 2018-05-15 13:01:12+00:00
# 21000            1 2018-05-15 13:01:12+00:00
# 21013            1 2018-05-15 13:01:12+00:00
# 21026            1 2018-05-15 13:01:12+00:00
# 21038            1 2018-05-15 13:01:12+00:00
# 21051            1 2018-05-15 13:01:12+00:00
# 21063            1 2018-05-15 13:01:12+00:00
# 21073            1 2018-05-15 13:01:12+00:00
# 21084            1 2018-05-15 13:01:12+00:00
# 21094            1 2018-05-15 13:01:12+00:00
# 21104            1 2018-05-15 13:01:12+00:00
# 21116            1 2018-05-15 13:01:12+00:00
# 21129            1 2018-05-15 13:01:12+00:00
# 21142            1 2018-05-15 13:01:12+00:00
# 21155            1 2018-05-15 13:01:12+00:00
# 21168            1 2018-05-15 13:01:12+00:00
# 21181            1 2018-05-15 13:01:12+00:00
# 21193            1 2018-05-15 13:01:12+00:00
# 21205            1 2018-05-15 13:01:12+00:00
# 21218            1 2018-05-15 13:01:12+00:00
# 21233            1 2018-05-15 13:01:12+00:00
# 21248            1 2018-05-15 13:01:12+00:00
# 21263            1 2018-05-15 13:01:12+00:00
# 21280            1 2018-05-15 13:01:12+00:00
# 21296            1 2018-05-15 13:01:12+00:00
# 21313            1 2018-05-15 13:01:12+00:00
# 21329            1 2018-05-15 13:01:12+00:00
# 21346            1 2018-05-15 13:01:12+00:00
#
#                                                     tags     views   likes  \
# 20988  Trailer|"bohemian rhapsody"|"queen"|"freddie m...   4215671  161058
# 21000  Trailer|"bohemian rhapsody"|"queen"|"freddie m...   7641675  250546
# 21013  Trailer|"bohemian rhapsody"|"queen"|"freddie m...   9052821  279714
# 21026  Trailer|"bohemian rhapsody"|"queen"|"freddie m...   9871934  294809
# 21038  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  10535890  306123
# 21051  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  10998967  312905
# 21063  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  11308127  317806
# 21073  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  11554324  321244
# 21084  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  11781372  324613
# 21094  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  11963850  327292
# 21104  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  12159901  329785
# 21116  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  12322276  331738
# 21129  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  12467285  333653
# 21142  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  12590552  335180
# 21155  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  12700845  336625
# 21168  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  12834122  338251
# 21181  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  12887949  338755
# 21193  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  12968372  339695
# 21205  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  13056713  340595
# 21218  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  13140827  341526
# 21233  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  13206088  342334
# 21248  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  13288364  343373
# 21263  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  13340919  343972
# 21280  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  13401991  344701
# 21296  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  13459161  345343
# 21313  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  13551003  346313
# 21329  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  13576077  346586
# 21346  Trailer|"bohemian rhapsody"|"queen"|"freddie m...  13619534  347100
#
#        dislikes  ...  Trending_Month Trending_Day  Trending_Day_of_Week  \
# 20988      2198  ...               5           16                     2
# 21000      4393  ...               5           17                     3
# 21013      5398  ...               5           18                     4
# 21026      5701  ...               5           19                     5
# 21038      5936  ...               5           20                     6
# 21051      6079  ...               5           21                     0
# 21063      6190  ...               5           22                     1
# 21073      6259  ...               5           23                     2
# 21084      6345  ...               5           24                     3
# 21094      6403  ...               5           25                     4
# 21104      6460  ...               5           26                     5
# 21116      6523  ...               5           27                     6
# 21129      6589  ...               5           28                     0
# 21142      6623  ...               5           29                     1
# 21155      6650  ...               5           30                     2
# 21168      6702  ...               5           31                     3
# 21181      6727  ...               6            1                     4
# 21193      6753  ...               6            2                     5
# 21205      6789  ...               6            3                     6
# 21218      6810  ...               6            4                     0
# 21233      6838  ...               6            5                     1
# 21248      6856  ...               6            6                     2
# 21263      6866  ...               6            7                     3
# 21280      6871  ...               6            8                     4
# 21296      6888  ...               6            9                     5
# 21313      6909  ...               6           10                     6
# 21329      6913  ...               6           11                     0
# 21346      6923  ...               6           12                     1
#
#        Trending_DOW  publish_Year publish_Month  publish_Day  \
# 20988     Wednesday          2018             5           15
# 21000      Thursday          2018             5           15
# 21013        Friday          2018             5           15
# 21026      Saturday          2018             5           15
# 21038        Sunday          2018             5           15
# 21051        Monday          2018             5           15
# 21063       Tuesday          2018             5           15
# 21073     Wednesday          2018             5           15
# 21084      Thursday          2018             5           15
# 21094        Friday          2018             5           15
# 21104      Saturday          2018             5           15
# 21116        Sunday          2018             5           15
# 21129        Monday          2018             5           15
# 21142       Tuesday          2018             5           15
# 21155     Wednesday          2018             5           15
# 21168      Thursday          2018             5           15
# 21181        Friday          2018             5           15
# 21193      Saturday          2018             5           15
# 21205        Sunday          2018             5           15
# 21218        Monday          2018             5           15
# 21233       Tuesday          2018             5           15
# 21248     Wednesday          2018             5           15
# 21263      Thursday          2018             5           15
# 21280        Friday          2018             5           15
# 21296      Saturday          2018             5           15
# 21313        Sunday          2018             5           15
# 21329        Monday          2018             5           15
# 21346       Tuesday          2018             5           15
#
#       publish_Day_of_Week publish_DOW  Publish_Hour
# 20988                   1     Tuesday            13
# 21000                   1     Tuesday            13
# 21013                   1     Tuesday            13
# 21026                   1     Tuesday            13
# 21038                   1     Tuesday            13
# 21051                   1     Tuesday            13
# 21063                   1     Tuesday            13
# 21073                   1     Tuesday            13
# 21084                   1     Tuesday            13
# 21094                   1     Tuesday            13
# 21104                   1     Tuesday            13
# 21116                   1     Tuesday            13
# 21129                   1     Tuesday            13
# 21142                   1     Tuesday            13
# 21155                   1     Tuesday            13
# 21168                   1     Tuesday            13
# 21181                   1     Tuesday            13
# 21193                   1     Tuesday            13
# 21205                   1     Tuesday            13
# 21218                   1     Tuesday            13
# 21233                   1     Tuesday            13
# 21248                   1     Tuesday            13
# 21263                   1     Tuesday            13
# 21280                   1     Tuesday            13
# 21296                   1     Tuesday            13
# 21313                   1     Tuesday            13
# 21329                   1     Tuesday            13
# 21346                   1     Tuesday            13
#
# [28 rows x 30 columns]

# %%
df=df_youtube   
df=df[['channel_title', 'views' ]].groupby(df['channel_title']).count() 
df=df[df['views'] > 120]
df.sort_values(by='views', inplace=True, ascending=False)
  
y1=df['views'] 
fig, (ax, ax1) = plt.subplots(2, figsize=(18,6))
ax = plt.subplot(111) 
ax.bar(y1.index, y1, width=.75 )  
ax.set(title='top channels', ylabel='trended', xlabel='chans')  
ax.legend(['channel'] , loc='best')   
plt.setp(ax.xaxis.get_majorticklabels(), rotation=80)
plt.show() 
df_topchannels=df

# %%
df=df_youtube
pindx = 0
fig,(ax) = plt.subplots(2, figsize=(18, 32)) 
channels = df_topchannels[:12].index 
rows=int((len(channels)+1)/2 ) 
for ch in channels: 
    df=df_youtube
    df=df[ (df['channel_title']  == ch) ]
    df=df[['channel_title', 'likes', 'dislikes', 'views', 'comment_count']].groupby(df['trending_date']).sum() 
    y=df['views']  
    pindx=pindx+1
    plt.style.use('ggplot')
    ax = plt.subplot(rows, 2, pindx) 
    ax.scatter( df['views'], df['likes'], color="y"  )   
    ax.scatter( df['views'], df['dislikes'], color="m" )  
    ax.scatter( df['views'], df['comment_count'], color="gray" )   
    ax.set(title=f'{ch} likes/dislikes/comment count', ylabel='likes/dislikes/comment count', xlabel='views')
    ax.legend([f'{ch} likes', f'{ch} dislikes', f'{ch} comment count'] , loc='best') 
plt.show()

# %%
df=df_youtube
tags = ['sexy','danger','cat"','taco']
pindx = 0
fig,(ax) = plt.subplots(2, figsize=(14, 12))  
rows=int((len(tags)+1)/2 ) 
for tag in tags:
    df=df_youtube
    df=df.loc[df['tags'].str.contains(tag)]   
    df=df.groupby(df['Publish_Hour'] ).sum()  
    pindx=pindx+1
    ax = plt.subplot(rows, 2, pindx) 
    plt.style.use('ggplot')
    ax.plot(df.index, df['likes']  ) 
    ax.plot(df.index, df['dislikes']  ) 
    ax.plot(df.index, df['comment_count']  ) 
    ax.set(title=f'"{tag}" Tagged (Views)', ylabel='views', xlabel='Publish_Hour')
    ax.legend([ f'"{tag}" Likes'
               , f'"{tag}" Dis'
               , f'"{tag}" Comments'] , loc='best') 
 
plt.show()

# %%
df=df_youtube
df=df[["title","dislikes"]]
df.drop_duplicates("title",keep="last",inplace=True)
df=df.sort_values("dislikes",ascending=False).head(25)
sns.set(rc={"figure.figsize":(24,5)})
plt.style.use('ggplot')
df.plot.bar(x="title", y="dislikes")

# %%
df=df_youtube
tags = ['challenge','turkey','holiday','drunk','taco','pregnant' ]
pindx = 0
fig,(ax) = plt.subplots(2, figsize=(22, 22))  
rows=int((len(tags)+1)/2 )  
for tag in tags:
    df=df_youtube
    df=df.loc[df['tags'].str.contains(tag)]   
    df=df.groupby(df['Trending_Month']).sum()  
    pindx=pindx+1
    ax = plt.subplot(rows, 2, pindx)  
    ax.plot(df.index, df['views']  ) 
    ax.set(title=f'"{tag}" Tagged (Views)', ylabel='views', xlabel='Trending_Month')
    ax.legend([ f'"{tag}" Views' ] , loc='best') 
 
plt.show()

# %%
df=df_youtube
t1 = 'taco'
t2 = 'pregnant'
df_t1=df.loc[df['tags'].str.contains(t1)]  
df_t1=df_t1[['views']].groupby(df['Trending_Month'] ).sum()  
df_t2=df.loc[df['tags'].str.contains(t2)]  
df_t2=df_t2[['views']].groupby(df['Trending_Month'] ).sum()  
df_year = pd.DataFrame({'Trending_Month':range(13)} )
df_year = pd.merge(df_year , df_t1, left_on='Trending_Month', right_on='Trending_Month', how="left", suffixes=['','_x'] )
df_year = pd.merge(df_year , df_t2, left_on='Trending_Month', right_on='Trending_Month', how="left", suffixes=['','_y'] )
df_year.fillna(0, inplace=True)
#print(df_year)

fig,(ax) = plt.subplots(2, figsize=(12, 4))   
ax = plt.subplot(1,1, 1)  
ax.plot(df_year.index, df_year['views']  )   
ax.plot(df_year.index, df_year['views_y']  )   
ax.legend([ f'"{t1}" Trend', f'"{t2}" Trend' ] , loc='best') 
plt.show()

# %%
df=df_youtube
df=df.groupby('video_id', as_index=False).count().sort_values(by='views', ascending=False)  
vids = df[32:38]['video_id']

# %%
df=df_youtube 
pindx = 0
fig,(ax) = plt.subplots(2, figsize=(18, 24))  
rows=int((len(vids)+1)/2 ) 
cx = 'trending_date'
cy = 'views'
cy2 = 'likes'
cz = 'trending_date' 
for vid in vids:
    df=df_youtube
    df=df[df['video_id']==vid]  
    pindx=pindx+1  
    x=df[cx] 
    print(df.iloc[0]['title']+' '+ df.iloc[0]['snippet.title'])
    t=df.iloc[0]['title'] +' '+ df.iloc[0]['snippet.title']
    ax = plt.subplot(rows, 2, pindx) 
    ax.plot(df[cx], df[cy] )   
    ax.set(title=f'{t}', ylabel='views', xlabel='time')
    ax.legend([f'{cy}'], loc='best')  
    plt.setp(ax.xaxis.get_majorticklabels(), rotation=70)     
plt.show()
# Out:
# Nicki Minaj  ChunLi Live on SNL   Music
# Lucas the Spider  Giant Spider Film & Animation
# Game of Zones  SE The Isle of Van Gundy Shows
# SZA  Garden Say It Like Dat Official Video Music
# Childish Gambino  This Is America Official Video Music
# Just Like You Left It Comedy

# %%
df=df_youtube  
df=df.groupby(df['publish_DOW']).count()  
df.sort_values(by="publish_Day_of_Week", inplace=True)

# %%
fig,(ax) = plt.subplots(1, figsize=(24, 6)) 
ax = plt.subplot(1, 1, 1)  
ax.bar(df.index, df['views']  )
ax.set(title=f'publish_DOW', ylabel='views', xlabel='publish_DOW')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
plt.show()

# %%
y = df_youtube['snippet.title'].value_counts() 
fig,  (ax) = plt.subplots(1, figsize=(24, 6)) 
ax = plt.subplot(111) 
ax.bar(y.index, y, width=.85 )  
ax.set(title='cats', ylabel='vid count', xlabel='cats')
ax.legend(['cats'] , loc='best') 
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
plt.show()

# %%
df=df_youtube
df=df[['snippet.title', 'views', 'likes', 'dislikes', 'comment_count']].groupby(df['snippet.title']).sum()
y1=df['likes']
y2=df['dislikes'] 
y3=df['comment_count'] 
fig, (ax, ax1) = plt.subplots(2, figsize=(24,16))
ax = plt.subplot(211) 
ax.bar(y1.index, y1, width=.55, color='y' ) 
ax.bar(y2.index, y2, width=.55, color='r' )   
ax.set(title='like / dislike', ylabel='like', xlabel='Cats')  
ax.legend((['like', 'dislike']) , loc='best') 
ax1.bar(y2.index, y3, width=.55, color='purple' )  
ax1.set(title='comment_count', ylabel='comment_count', xlabel='cats')
ax1.legend(['comment_count'] , loc='best')  
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
plt.show()

# %%
class Main(object):
    def __init__(self):
        self.context = ''
    def tomodel(self, col_names):
        d = {}
        #subprocess.call(["C:\\Users\\Tim\\AppData\\Local\\Programs\\Microsoft VS Code\\Code.exe" ]) 
        for col_name in col_names:  
            key = col_name
            for char in col_name: 
                if not char.isalpha():
                    key = key.replace(char,'')        
            d[key] = col_name.replace('\'','').replace('  ','').strip()
        return d  
    def tonum(num):
        try:
            num=re.sub('\D', '', str(num))
        except:
            print (num)  
        return num.astype(float)
m = Main()
m.tomodel(df_providers.columns)

# %%
#df_main= df.rename(columns=lambda x: ''.join([c for c in x if c.isalpha()]), inplace=True)#╭∩╮(Ο_Ο)╭∩╮
