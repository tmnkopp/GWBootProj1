# %%
import pandas as pd
import numpy as np 
import re  
import json
import random
from scipy.stats import logistic
import seaborn as sns
import matplotlib.pyplot as plt 
import calendar
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#df_usvideos = pd.read_csv('data/youtube/USvideos.csv')
df_usvideos = pd.read_csv('data/youtube/ustrend.csv')
json_cats = pd.read_json('data/youtube/US_category_id.json')
df_cats = pd.json_normalize(json_cats['items'])

# %%
# Out:
#           video_id                                              title  \
# 0      3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1      M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2      J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3      kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4      VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# ...            ...                                                ...
# 17193  5mJ35Kz96AI         Carin Leon & Grupo Firme - Amor Borrachito
# 17194  Yl_-3oSlWaU  Busta Rhymes - Look Over Your Shoulder (Lyric ...
# 17195  Z2YLEPFa750  The GMC Hummer EV Is an Insane $100,000+ Elect...
# 17196  ePZP3SAGkrY                                Karen Support Group
# 17197  Sgrjiqh6rlk  7.0 Earthquake In Aegean Sea Shakes Turkey, Gr...
#
#                 publishedAt                 channelId          channelTitle  \
# ...

# %%
print(df_cats.info()) 
print(df_usvideos.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   kind                32 non-null     object
#  1   etag                32 non-null     object
#  2   id                  32 non-null     object
#  3   snippet.channelId   32 non-null     object
#  4   snippet.title       32 non-null     object
#  5   snippet.assignable  32 non-null     bool
# dtypes: bool(1), object(5)
# memory usage: 1.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17198 entries, 0 to 17197
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   video_id           17198 non-null  object
#  1   title              17198 non-null  object
#  2   publishedAt        17198 non-null  object
#  3   channelId          17198 non-null  object
# ...

# %%
df_usvideos.head(2)
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
#
#             publishedAt                 channelId  channelTitle  categoryId  \
# 0  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg      Brawadis          22
# 1  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A  Apex Legends          20
#
#           trending_date                                               tags  \
# 0  2020-08-12T00:00:00Z  brawadis|prank|basketball|skits|ghost|funny vi...
# 1  2020-08-12T00:00:00Z  Apex Legends|Apex Legends characters|new Apex ...
#
#    view_count   likes  dislikes  comment_count  \
# 0     1514614  156908      5855          35313
# 1     2381688  146739      2794          16549
#
#                                    thumbnail_link  comments_disabled  \
# 0  https://i.ytimg.com/vi/3C66w5Z0ixs/default.jpg              False
# ...

# %%
df_cats.head(2)
# Out:
#                     kind                                               etag  \
# 0  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_BmKm...
# 1  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/UZ1oLIIz2dxIhO45Z...
#
#   id         snippet.channelId     snippet.title  snippet.assignable
# 0  1  UCBR8-60-B28hp2BmDPdntcQ  Film & Animation                True
# 1  2  UCBR8-60-B28hp2BmDPdntcQ  Autos & Vehicles                True

# %%
df_cats['id']=df_cats['id'].astype(int)  
df = pd.merge(
        df_usvideos
      , df_cats
      , left_on=['categoryId']
      , right_on=['id']
      , suffixes=['','{இ}ڿڰۣ-ڰۣ~—']
     )
df.drop(
    [c for c in df.columns if '{இ}ڿڰۣ-ڰۣ~—' in c]
    , axis=1
    , inplace=True
    )
df_youtube=df

# %%
df=df_youtube
df=df.rename(columns=
                    {'publishedAt':'publish_time'
                    , 'categoryId':'category_id'
                    , 'view_count':'views'
                    , 'channelId':'channel_title'
                    })  
for col in ["views likes dislikes comment_count".split()]:
    df[col]=df[col].astype(int)
     
df=df[['video_id', 'trending_date', 'title', 'channelTitle', 'channel_title', 'category_id',
       'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
       'thumbnail_link', 'comments_disabled', 'ratings_disabled', 
       'description','snippet.title']]

df['trending_date']=df['trending_date'].apply(lambda t:t.split('T')[0]) 
df['comments_disabled']=df['comments_disabled'].map({True:1, False:0})  
df['ratings_disabled']=df['ratings_disabled'].map({True:1, False:0}) 
df['catname']=df['snippet.title'] 
df['pk_youtube'] = range(len(df))
df.set_index('pk_youtube', inplace=True)
df_youtube=df

# %%
df_youtube=df

# %%
df=df_youtube
dict_day_name=dict(enumerate(calendar.day_name))  
df['publish_time']=pd.to_datetime(df['publish_time'])
df['trending_date']=pd.to_datetime(df['trending_date'],format="%Y-%m-%d")
df["Trending_Year"]=df["trending_date"].apply(lambda t:t.year)
df["Trending_Month"]=df["trending_date"].apply(lambda t:t.month)
df["Trending_MonthName"]=df["Trending_Month"].apply(lambda t:calendar.month_name[t])
df["Trending_Day"]=df["trending_date"].apply(lambda t:t.day) 
df["Trending_Day_of_Week"]=df["trending_date"].apply(lambda t:t.dayofweek) 
df["Trending_DOW"]=df["Trending_Day_of_Week"].map(dict_day_name)
df["publish_Year"]=df["publish_time"].apply(lambda t:t.year)
df["publish_Month"]=df["publish_time"].apply(lambda t:t.month)
df["publish_Day"]=df["publish_time"].apply(lambda t:t.day)
df["publish_Day_of_Week"]=df["publish_time"].apply(lambda t:t.dayofweek)
df["publish_DOW"]=df["publish_Day_of_Week"].map(dict_day_name) 
df["publish_MonthName"]=df["publish_Month"].apply(lambda t:calendar.month_name[t])
df["Publish_Hour"]=df["publish_time"].apply(lambda t:t.hour)  
df["title"]=df["title"].apply(lambda t: ''.join([c for c in t if (c.isalpha()) or (c.isspace())]))
df.sort_values(by=['trending_date'], ascending=True, inplace=True) 
#df[2:len(df):5000]
#print(df.info())
#df['trending_date'].value_counts()

# %%
df=df_youtube
df['sentiment_reactions'] = df['likes']+df['dislikes']
df['all_reactions']=df['sentiment_reactions']+df['comment_count']
df['per_like'] = round(df['likes']/df['sentiment_reactions'], 4)
df['per_dislike'] = round(df['dislikes']/df['sentiment_reactions'], 4)
df.head(6)
# Out:
#                video_id trending_date  \
# pk_youtube
# 0           3C66w5Z0ixs    2020-08-12
# 14567       0a5YhsnITFE    2020-08-12
# 14568       kzST_Q2Xbks    2020-08-12
# 14569       TUlFDVUTsKg    2020-08-12
# 14570       qq7MSjXHRTU    2020-08-12
# 14571       RsmttAEp9f4    2020-08-12
#
#                                                         title  \
# pk_youtube
# 0                             I ASKED HER TO BE MY GIRLFRIEND
# 14567                          LFR  QR Game   Done  CBJ  Tor
# 14568       Draymond Green Shares Why Hes Picking LeBron a...
# 14569       Highlights  Man City  Real Madrid  Champions L...
# 14570       Barcelona vs Napoli  Champions League Round of...
# 14571       Bayern Munich vs Chelsea  Champions League Rou...
#
#                               channelTitle             channel_title  \
# pk_youtube
# 0                                 Brawadis  UCvtRTOMP2TqYqu51xNrqAzg
# 14567                          SteveDangle  UCkUjSzthJUlO0uyUpiJfnxg
# ...

# %%
df=df_youtube
df=df.groupby(['video_id', 'title',  'catname','tags', 'trending_date'], as_index=False).sum().sort_values(by='views', ascending=False)   
print(df['video_id'].count())
df=df[['video_id','title',  'catname', 'tags', 'views','likes', 'dislikes', 'trending_date']] 
df=df[~df['tags'].isin(['K-pop'])]
df_trends=df.iloc[222:223]
df_trends=df.loc[df['video_id']=='Wsije1KetVw']
df_trends.sort_values(by='views', ascending=True, inplace=True) 
df_trends
# Out:
# 17197
#          video_id                        title        catname  \
# 9150  Wsije1KetVw  First Debate Cold Open  SNL  Entertainment
# 9151  Wsije1KetVw  First Debate Cold Open  SNL  Entertainment
# 9152  Wsije1KetVw  First Debate Cold Open  SNL  Entertainment
# 9153  Wsije1KetVw  First Debate Cold Open  SNL  Entertainment
# 9154  Wsije1KetVw  First Debate Cold Open  SNL  Entertainment
# 9155  Wsije1KetVw  First Debate Cold Open  SNL  Entertainment
# 9156  Wsije1KetVw  First Debate Cold Open  SNL  Entertainment
# 9157  Wsije1KetVw  First Debate Cold Open  SNL  Entertainment
#
#                                                    tags     views   likes  \
# 9150  snl|saturday night live|season 46|snl 46|fox|p...  10377620  227472
# 9151  snl|saturday night live|season 46|snl 46|fox|p...  14111945  289642
# 9152  snl|saturday night live|season 46|snl 46|fox|p...  16606294  340492
# 9153  snl|saturday night live|season 46|snl 46|fox|p...  18705609  381733
# ...

# %%
df=df_youtube
df=df[df['trending_date']=='2020-10-05']
df=df.head(20)
print(df['video_id'].count())
fig,(ax) = plt.subplots(1,figsize=(6,6))
ax.scatter( df['views'], df['per_like']  ) 
plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)
plt.show()
# Out:
# 20

# %%
df=df.groupby('video_id', as_index=False).sum() 
df.sort_values('views', ascending=False, inplace=True)
set_most_viewed_video_ids = set(df['video_id'].head(4))

# %%
df=df_youtube   
df=df[['title', 'views' ]].groupby(df['channelTitle']).count() 
df=df[df['views'] > 60]
df.sort_values(by='views', inplace=True, ascending=False)
 
fig, (ax) = plt.subplots(1, figsize=(24,3)) 
ax = plt.subplot(111) 
ax.bar(df.index.values, df['views'], width=.45 )  
ax.set(title='top channels', ylabel='views', xlabel='chans')   
plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)
plt.show() 
df_topchannels=df

# %%
df=df_youtube
df=df[(df['trending_date'] == '2020-10-01')]
df=df[['title', 'likes', 'dislikes', 'views', 'comment_count']].groupby(df['channelTitle']).sum() 
df.sort_values(by="views", ascending=False, inplace=True)
df=df.head(10)
df
# Out:
#                                           likes  dislikes     views  \
# channelTitle
# JustinBieberVEVO                        2464848     61514  42443791
# MrBeast                                 1118944     11901  18885051
# MrBeast Gaming                           850406     13333  18717037
# The Tonight Show Starring Jimmy Fallon  2780860     26477  18579816
# Big Hit Labels                          2437545     30248  16704233
# Jennifer Lopez                           511407     24198  14511982
# TravisScottVEVO                          719510     16424  13972677
# ZaynVEVO                                1197618     15959  11338460
# melanie martinez                         936490     23810  11195950
# Tory Lanez                               198896     12225  10944206
#
#                                         comment_count
# channelTitle
# JustinBieberVEVO                               183663
# MrBeast                                         59571
# ...

# %%
fig, (ax, ax1) = plt.subplots(2, figsize=(16,14))
ax = plt.subplot(211) 
#ax.bar(df.index.values, df['views'], width=.75 )  
ax.bar(df.index.values, df['likes'], width=.75, color="y"  )  
ax.set(title='top channels', ylabel='trended', xlabel='channelTitle')  
ax.legend(['likes'] , loc='best')   
ax1 = plt.subplot(212) 
ax1.bar(df.index.values, df['dislikes'], width=.75, color="r" ) 
ax1.legend(['dislikes'] , loc='best')  
plt.setp(ax.xaxis.get_majorticklabels(), rotation=60)
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=60)
plt.show()

# %%
df=df_youtube
df=df[(df['trending_date'] > '2020-10-01')]
df=df[[
         'views','video_id','likes','per_like','per_dislike', 'catname' 
    ]].groupby([
         'catname','video_id' 
    ], as_index=False
    ).agg(
        {'likes':['mean', 'sum']
         ,'per_like':['mean']
         ,'per_dislike':['mean']
        }
    )
 
df.sort_values(by='video_id', ascending=True, inplace=True) 
df=df.head(15)
df[0:len(df)-2:int(len(df)/5)]
# Out:
#              catname     video_id          likes           per_like  \
#                                             mean      sum      mean
# 1111  People & Blogs  -0kb-gs-GKc  151273.000000   453819  0.994067
# 713            Music  -7RVbpldizM   24712.428571   172987  0.983857
# 714            Music  -G3mOwOAwT8   94353.666667   283061  0.985667
# 715            Music  -ToHbHcolfA  497146.600000  2485733  0.992500
# 23            Comedy  -Zeyodzl0qo   13393.166667    80359  0.960300
#
#      per_dislike
#             mean
# 1111    0.005933
# 713     0.016143
# 714     0.014333
# 715     0.007500
# 23      0.039700

# %%
df=df_youtube
pindx = 0
fig,(ax) = plt.subplots(2, figsize=(18, 32)) 
channels = df_topchannels[:12].index 
rows=int((len(channels)+1)/2 ) 
for ch in channels: 
    df=df_youtube
    df=df[df['channelTitle']  == ch]
    df=df[['title', 'likes', 'dislikes', 'views', 'comment_count']].groupby(df['trending_date']).sum() 
    y=df['views']  
    pindx=pindx+1
    
    ax = plt.subplot(rows, 2, pindx) 
    ax.scatter( df['views'], df['likes'], color="y"  )   
    ax.scatter( df['views'], df['dislikes'], color="m" )  
    ax.scatter( df['views'], df['comment_count'], color="gray" )   
    ax.set(title=f'{ch} likes/dislikes/comment count', ylabel='likes/dislikes/comment count', xlabel='views')
    ax.legend([f'{ch} likes', f'{ch} dislikes', f'{ch} comment count'] , loc='best') 
plt.show()

# %%
df=df_youtube  
for grp in ['snippet.title','publish_time']:
    df=df_youtube 
    fig,(ax) = plt.subplots(1, figsize=(34, 6))  
    df=df.loc[df['tags'].str.contains('challenge')].groupby(df[grp]).sum()  
    ax.bar(df.index, df['views']) 
    plt.setp(ax.xaxis.get_majorticklabels(), rotation=60) 
    ax.set(title="challenge")
plt.show()

# %%
df=df_youtube
df=df.loc[df['tags'].str.contains('challenge')].groupby('snippet.title', as_index=False).sum()
df.sort_values(by='views', ascending=False, inplace=True)
challenge_cats = df.head(5)
challenge_cats = set(challenge_cats['snippet.title'])
challenge_cats
# Out:
# {'Entertainment', 'Gaming', 'Howto & Style', 'Music', 'People & Blogs'}

# %%
pindx = 0
fig,(ax) = plt.subplots(2, figsize=(24, 46))  
rows=int((len(channels)+1)/2 ) 
for cat in challenge_cats:
    df=df_youtube.loc[df_youtube['tags'].str.contains('challenge')] 
    df=df.loc[(df['snippet.title'] == cat)]
    df=df.groupby(['publish_time'] ).mean()   
    if len(df['views']) > 9:
        pindx=pindx+1
        ax = plt.subplot(rows, 2, pindx)         
        ax.scatter(df.index, df['views'])   
        plt.setp(ax.xaxis.get_majorticklabels(), rotation=60) 
        ax.set(title=cat) 
plt.show()

# %%
df=df_youtube
df=df[["title","dislikes"]]
df.drop_duplicates("title",keep="last",inplace=True)
df=df.sort_values("dislikes",ascending=False).head(25)
sns.set(rc={"figure.figsize":(24,5)})
plt.style.use('ggplot')
df.plot.bar(x="title", y="dislikes")

# %%
df=df_youtube
df.sort_values(by="Trending_Day", inplace=True)
tags = ['beer','pregnant']
pindx = 0
fig,(ax) = plt.subplots(2, figsize=(22, 12))  
rows=int((len(tags)+1)/2 )  
for tag in tags:
    df=df_youtube
    df=df.loc[df['tags'].str.contains(tag)]   
    df=df.groupby(df['Trending_DOW']).sum()
      
    pindx=pindx+1
    ax = plt.subplot(rows, 2, pindx)  
    ax.plot(df.index, df['views']  ) 
    ax.set(title=f'"{tag}" Tagged (Views)', ylabel='views', )
    ax.legend([ f'"{tag}" Views' ] , loc='best') 
 
plt.show()

# %%
df=df_youtube
df=df[df['trending_date']=='2020-10-01']   
df_trend_day=df
df=df[df['Trending_Month']==10]   
df_trend_month=df
df_trend_month
# Out:
#                video_id trending_date  \
# pk_youtube
# 15762       cXqRUDglvcs    2020-10-01
# 15780       MJB0gCoQYoo    2020-10-01
# 2277        z-r2AhqxBzw    2020-10-01
# 2275        l4pX35OW1S4    2020-10-01
# 12854       cH66LWWluVE    2020-10-01
# ...                 ...           ...
# 2267        gi-63nX4BoM    2020-10-01
# 11107       SoGCIuO2XkM    2020-10-01
# 11106       w1zzOyksUGo    2020-10-01
# 11104       wbR-5mHI6bo    2020-10-01
# 11101       dDYFiq1l5Dg    2020-10-01
#
#                                                         title  \
# pk_youtube
# 15762                Packers vs Saints Week  Highlights  NFL
# 15780       Stan Wawrinka vs Andy Murray  Round  Highlight...
# 2277                   Assassins Creed Valhalla Story Trailer
# 2275        Crown Tundra Update Reaction  Pokémon Sword Ex...
# 12854                The Ultimate iOS  Homescreen Setup Guide
# ...                                                       ...
# ...

# %%
df=df_trend_day.head(15)
fig,(ax) = plt.subplots(1, figsize=(22, 6))  
ax = plt.subplot(1, 1, 1) 
ax.scatter(df['channelTitle'], df['views'] ) 
df=df_trend_month.head(15)
ax.scatter(df['channelTitle'], df['all_reactions'] )

plt.setp(ax.xaxis.get_majorticklabels(), rotation=70)      
plt.show()

# %%
df=df_youtube  
df=df.groupby(df['publish_DOW']).count()  
df.sort_values(by="publish_Day_of_Week", inplace=True)

# %%
fig,(ax) = plt.subplots(1, figsize=(24, 6)) 
ax = plt.subplot(1, 1, 1)  
ax.bar(df.index, df['views']  )
ax.set(title=f'publish_DOW', ylabel='views', xlabel='publish_DOW')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
plt.show()

# %%
y = df_youtube['snippet.title'].value_counts() 
fig,  (ax) = plt.subplots(1, figsize=(24, 6)) 
ax = plt.subplot(111) 
ax.bar(y.index, y, width=.85 )  
ax.set(title='cats', ylabel='vid count', xlabel='cats')
ax.legend(['cats'] , loc='best') 
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
plt.show()

# %%
df=df_youtube
df=df[['snippet.title', 'views', 'likes', 'dislikes', 'comment_count']].groupby(df['snippet.title']).sum()
y1=df['likes']
y2=df['dislikes'] 
y3=df['comment_count'] 
fig, (ax, ax1) = plt.subplots(2, figsize=(24,16))
ax = plt.subplot(211) 
ax.bar(y1.index, y1, width=.55, color='y' ) 
ax.bar(y2.index, y2, width=.55, color='r' )    
ax.set(title='like / dislike', ylabel='like', xlabel='Cats')  
ax.legend((['like', 'dislike']) , loc='best') 
ax1.bar(y2.index, y3, width=.55, color='purple' )  
ax1.set(title='comment_count', ylabel='comment_count', xlabel='cats')
ax1.legend(['comment_count'] , loc='best')  
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
plt.show()

# %%
class Main(object):
    def __init__(self):
        self.context = ''
    def tomodel(self, col_names):
        d = {}
        #subprocess.call(["C:\\Users\\Tim\\AppData\\Local\\Programs\\Microsoft VS Code\\Code.exe" ]) 
        for col_name in col_names:  
            key = col_name
            for char in col_name: 
                if not char.isalpha():
                    key = key.replace(char,'')        
            d[key] = col_name.replace('\'','').replace('  ','').strip()
        return d  
    def tonum(num):
        try:
            num=re.sub('\D', '', str(num))
        except:
            print (num)  
        return num.astype(float)
m = Main()
m.tomodel(df.columns)
# Out:
# {'views': 'views',
#  'likes': 'likes',
#  'dislikes': 'dislikes',
#  'commentcount': 'comment_count'}

# %%
#df_main= df.rename(columns=lambda x: ''.join([c for c in x if c.isalpha()]), inplace=True)#╭∩╮(Ο_Ο)╭∩╮
